# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import stats
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, HistGradientBoostingClassifier
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score, accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from joblib import dump, load
from xgboost import XGBClassifier
plt.rcParams['figure.figsize'] = [20,10]

# %%
data = pd.read_csv('transactions_train.csv')
responseVar = data.isFraud.to_numpy()
responseVar
data['deltaBalanceOrig'] = data.newbalanceOrig - data.oldbalanceOrig
data['deltaBalanceDest'] = -data.newbalanceDest + data.oldbalanceDest
data['prevStep'] = data['step'].shift(1)
data['prevAmt'] = data['amount'].shift(1)
data['prevType'] = 0

# %%
fig,((ax,ax1,ax2),(ax3,ax4,ax5)) = plt.subplots(2,3)
fig.subplots_adjust(hspace=0.8)
ax.hist(x=data['amount'],bins=1000,label='amount')
ax.set_xlim(0,1e6)
ax.set_title('Amount')
ax1.hist(x=data['oldbalanceOrig'],bins=1000,label='oldbalanceOrig')
ax1.set_xlim(0,1e6)
ax1.set_title('Old Balance Orig')
ax2.hist(x=data['newbalanceOrig'],bins=1000,label='newbalanceOrig')
ax2.set_xlim(0,1e6)
ax2.set_title('New Balance Orig')
ax3.hist(x=data['oldbalanceDest'],bins=1000,label='oldbalanceDest')
ax3.set_xlim(0,0.5e7)
ax3.set_title('Old Balance Dest')
ax4.hist(x=data['newbalanceDest'],bins=1000,label='newbalanceDest')
ax4.set_xlim(0,0.5e7)
ax4.set_title('New Balance Dest')
ax5.hist(x=data['deltaBalanceDest'],bins=1000,label='deltaBalanceDest',alpha=0.3)
ax5.hist(x=data['deltaBalanceOrig'],bins=1000,label='deltaBalanceOrig')
ax5.set_xlim(-1e6,1e6)
ax5.set_title('Delta Balance')
ax5.legend()

plt.show()

# %%
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrig  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815        170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295         21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145           181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671           181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720         41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  deltaBalanceOrig  \
# 0  M1979787155             0.0             0.0        0          -9839.64
# 1  M2044282225             0.0             0.0        0          -1864.28
# 2   C553264065             0.0             0.0        1           -181.00
# 3    C38997010         21182.0             0.0        1           -181.00
# 4  M1230701703             0.0             0.0        0         -11668.14
#
#    deltaBalanceDest  prevStep  prevAmt  prevType
# 0               0.0       NaN      NaN         0
# 1               0.0       1.0  9839.64         0
# 2               0.0       1.0  1864.28         0
# 3           21182.0       1.0   181.00         0
# 4               0.0       1.0   181.00         0

# %%
features = data.loc[:,['amount','deltaBalanceDest','step','prevStep','type',
                       'oldbalanceOrig','newbalanceOrig','newbalanceDest','oldbalanceDest','deltaBalanceOrig',
                    'prevAmt','prevType']]
features.shape
# Out:
# (6351193, 12)

# %%
cat_scaler = OrdinalEncoder().fit(features.loc[:,'type'].values.reshape(-1,1))
features.loc[:,'type'] = cat_scaler.transform(features.loc[:,'type'].values.reshape(-1,1))
features['prevType'] = features['type'].shift(1)
features
# Out:
#              amount  deltaBalanceDest  step  prevStep  type  oldbalanceOrig  \
# 0           9839.64              0.00     1       NaN   3.0       170136.00
# 1           1864.28              0.00     1       1.0   3.0        21249.00
# 2            181.00              0.00     1       1.0   4.0          181.00
# 3            181.00          21182.00     1       1.0   1.0          181.00
# 4          11668.14              0.00     1       1.0   3.0        41554.00
# ...             ...               ...   ...       ...   ...             ...
# 6351188   162326.52              0.00   699     699.0   4.0       162326.52
# 6351189   162326.52        -162326.52   699     699.0   1.0       162326.52
# 6351190  2763398.31              0.00   699     699.0   4.0      2763398.31
# 6351191  2763398.31       -2763398.31   699     699.0   1.0      2763398.31
# 6351192      578.21           -578.21   699     699.0   2.0        10575.00
#
#          newbalanceOrig  newbalanceDest  oldbalanceDest  deltaBalanceOrig  \
# 0             160296.36            0.00            0.00          -9839.64
# 1              19384.72            0.00            0.00          -1864.28
# 2                  0.00            0.00            0.00           -181.00
# 3                  0.00            0.00        21182.00           -181.00
# 4              29885.86            0.00            0.00         -11668.14
# ...                 ...             ...             ...               ...
# 6351188            0.00            0.00            0.00        -162326.52
# 6351189            0.00       162326.52            0.00        -162326.52
# 6351190            0.00            0.00            0.00       -2763398.31
# 6351191            0.00      3102913.66       339515.35       -2763398.31
# 6351192         9996.79       127650.44       127072.23           -578.21
#
#             prevAmt  prevType
# 0               NaN       NaN
# 1           9839.64       3.0
# 2           1864.28       3.0
# 3            181.00       4.0
# 4            181.00       1.0
# ...             ...       ...
# 6351188      573.88       3.0
# 6351189   162326.52       4.0
# 6351190   162326.52       1.0
# 6351191  2763398.31       4.0
# 6351192  2763398.31       1.0
#
# [6351193 rows x 12 columns]

# %%
seed = 42
Xtrain,Xtest,ytrain,ytest = train_test_split(features,responseVar,test_size=0.2,stratify=responseVar, random_state=seed)

# %%
mdl = XGBClassifier(use_label_encoder=False,verbosity=2)
mdl.fit(Xtrain,ytrain)
# Out:
# [13:18:46] INFO: ../src/gbm/gbtree.cc:147: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [13:18:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [13:18:51] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:18:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [13:19:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 84 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 72 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=6
# [13:20:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [13:21:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [13:22:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [13:23:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [13:24:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=6
# [13:25:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [13:26:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [13:26:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [13:26:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [13:26:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [13:26:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [13:26:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=6
# [13:26:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='approx', use_label_encoder=False,
#               validate_parameters=1, verbosity=2)

# %%
preds = mdl.predict(Xtest)
acc = accuracy_score(ytest,preds)
f1 = f1_score(ytest,preds)
prec = precision_score(ytest,preds)
recall = recall_score(ytest,preds)
AUC = roc_auc_score(ytest,preds)
print(acc, f1, prec, recall, AUC)
# Out:
# 0.9999803186644403 0.9918962722852512 0.9922178988326849 0.9915748541801686 0.9957826978247598

# %%
dump(mdl,'XGBoostModelFeatures12.joblib')
# Out:
# ['XGBoostModelFeatures12.joblib']

# %%
print(np.c_[features.columns,mdl.feature_importances_])
# Out:
# [['amount' 0.03294645994901657]
#  ['deltaBalanceDest' 0.07196873426437378]
#  ['step' 0.016811221837997437]
#  ['prevStep' 0.0042024035938084126]
#  ['type' 0.10744249820709229]
#  ['oldbalanceOrig' 0.062174081802368164]
#  ['newbalanceOrig' 0.1322542130947113]
#  ['newbalanceDest' 0.19758543372154236]
#  ['oldbalanceDest' 0.005805641412734985]
#  ['deltaBalanceOrig' 0.054761212319135666]
#  ['prevAmt' 0.0328485332429409]
#  ['prevType' 0.28119954466819763]]

# %%
plt.bar(features.columns,mdl.feature_importances_)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show()

# %%
cm = confusion_matrix(ytest, preds, labels=mdl.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=mdl.classes_)
disp.plot()
plt.show()

# %%
fpr, tpr, thresh = roc_curve(ytest,preds)
f, ax = plt.subplots(1)
ax.plot(fpr,tpr)
ax.plot([0,1])
plt.show()

# %%
features = features.iloc[:,:-1]
features
# Out:
#              amount  deltaBalanceDest  step  prevStep      type  \
# 0           9839.64              0.00     1       0.0   PAYMENT
# 1           1864.28              0.00     1       1.0   PAYMENT
# 2            181.00              0.00     1       1.0  TRANSFER
# 3            181.00          21182.00     1       1.0  CASH_OUT
# 4          11668.14              0.00     1       1.0   PAYMENT
# ...             ...               ...   ...       ...       ...
# 6351188   162326.52              0.00   699     699.0  TRANSFER
# 6351189   162326.52        -162326.52   699     699.0  CASH_OUT
# 6351190  2763398.31              0.00   699     699.0  TRANSFER
# 6351191  2763398.31       -2763398.31   699     699.0  CASH_OUT
# 6351192      578.21           -578.21   699     699.0     DEBIT
#
#          oldbalanceOrig  newbalanceOrig  newbalanceDest  oldbalanceDest
# 0             170136.00       160296.36            0.00            0.00
# 1              21249.00        19384.72            0.00            0.00
# 2                181.00            0.00            0.00            0.00
# 3                181.00            0.00            0.00        21182.00
# 4              41554.00        29885.86            0.00            0.00
# ...                 ...             ...             ...             ...
# 6351188       162326.52            0.00            0.00            0.00
# 6351189       162326.52            0.00       162326.52            0.00
# 6351190      2763398.31            0.00            0.00            0.00
# 6351191      2763398.31            0.00      3102913.66       339515.35
# 6351192        10575.00         9996.79       127650.44       127072.23
#
# [6351193 rows x 9 columns]

# %%
w = load('XGBoostModel.joblib')

# %%
Xt = Xtest.iloc[:,:-1]
Xt
# Out:
#             amount  deltaBalanceDest  step  prevStep  type  oldbalanceOrig  \
# 3566285    6401.18              0.00   260     260.0   3.0       228134.00
# 93688    161307.22       -1097112.95    10      10.0   1.0        40068.00
# 6105744  282176.18        -282176.18   525     525.0   4.0       548709.00
# 1162632  251078.44        -251078.44   132     132.0   1.0          133.00
# 1519501    5523.21              0.00   153     153.0   3.0        19893.00
# ...            ...               ...   ...       ...   ...             ...
# 6260758  263974.68         263974.68   608     608.0   0.0      8691597.97
# 942816   248249.00        -248249.00    43      43.0   1.0         1017.00
# 6148111  299344.24        -299344.24   546     546.0   1.0            0.00
# 3218539  213435.28         -25893.40   250     250.0   4.0            0.00
# 3567586     589.59              0.00   260     260.0   3.0       128299.48
#
#          newbalanceOrig  newbalanceDest  oldbalanceDest
# 3566285       221732.82            0.00            0.00
# 93688              0.00      1140934.55        43821.60
# 6105744       266532.82       282176.18            0.00
# 1162632            0.00       251078.44            0.00
# 1519501        14369.79            0.00            0.00
# ...                 ...             ...             ...
# 6260758      8955572.65       183869.53       447844.21
# 942816             0.00      2213640.95      1965391.95
# 6148111            0.00      1463551.96      1164207.72
# 3218539            0.00       887818.03       861924.63
# 3567586       127709.89            0.00            0.00
#
# [1270239 rows x 9 columns]

# %%
preds = w.predict(Xt)
acc = accuracy_score(ytest,preds)
f1 = f1_score(ytest,preds)
prec = precision_score(ytest,preds)
recall = recall_score(ytest,preds)
AUC = roc_auc_score(ytest,preds)
print(acc, f1, prec, recall, AUC)
# Out:
# 0.9997787817883091 0.9034032313509798 0.9619326500732065 0.8515878159429683 0.9257734144884117

# %%
print(np.c_[features.columns,w.feature_importances_])
# Out:
# [['amount' 0.06329754739999771]
#  ['deltaBalanceDest' 0.1356649398803711]
#  ['step' 0.026064880192279816]
#  ['prevStep' 0.05457758158445358]
#  ['type' 0.14395345747470856]
#  ['oldbalanceOrig' 0.17576470971107483]
#  ['newbalanceOrig' 0.2830684781074524]
#  ['newbalanceDest' 0.103801429271698]
#  ['oldbalanceDest' 0.01380709558725357]]

# %%
dump(cat_scaler,'TypeScaler.joblib')
# Out:
# ['TypeScaler.joblib']

# %%
cat_scaler.categories_
# Out:
# [array(['CASH_IN', 'CASH_OUT', 'DEBIT', 'PAYMENT', 'TRANSFER'],
#        dtype=object)]

# %%
nameOrigCount = data.groupby('nameDest',sort=True).size()
nameMaxOrig = nameOrigCount.idxmax()
nameMaxOrig
# Out:
# 'C1286084959'

# %%
w = nameOrigCount.sort_values(ascending=False)
w[:50]
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# C977993101      96
# C97730845       96
# C392292416      95
# C1899073220     92
# C306206744      91
# C1782113663     90
# C1234776885     90
# C716083600      89
# C998351292      89
# C909295153      88
# C1674899618     86
# C667346055      86
# C1262822392     85
# C1816757085     84
# C453211571      84
# C1255024717     84
# C2006081398     83
# C1504109395     82
# C991363637      82
# C932583850      82
# C728526866      81
# C1303868418     81
# C1721246982     80
# C33524623       80
# C214774813      80
# C1870252780     80
# C11003494       80
# C766681183      80
# C1883840933     80
# C1909597726     80
# C662736689      79
# C1167066016     79
# C769342184      78
# C803116137      77
# C423580937      77
# C1730752455     76
# C1850180796     76
# C1297685781     76
# C914293025      75
# C2049813033     75
# dtype: int64
